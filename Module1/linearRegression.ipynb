# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_model as lr

# %%
data = pd.read_csv('cost_revenue_clean.csv')

# %%
# data.describe()

# %%
X = pd.DataFrame(data=data, columns=['production_budget_usd'])
y = pd.DataFrame(data=data, columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X, y, alpha=0.3)
plt.ylabel('Production budget $')
plt.xlabel('Worldwide Gross $')
plt.title('Film cost vs Global Revenue')
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.show()

# %%
regression = lr.LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([[3.11150918]])

# %%
regression.intercept_
# Out:
# array([-7236192.72913963])

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X, y, alpha=0.3)
plt.plot(X, regression.predict(X), color='red', linewidth = 3)
plt.scatter(pd.DataFrame(data=[125000000]), pd.DataFrame([1341511254]), color='green')
plt.ylabel('Production budget $')
plt.xlabel('Worldwide Gross $')
plt.title('Film cost vs Global Revenue')
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.show()

# %%
# print(type(X))
# print(type(y))
# print(type(a))
# print(type(b))

# print(X)
# print(y)
a, b = pd.DataFrame(data=[125000000]), pd.DataFrame([1341511254])

# print(a)
# print(b)

ans = regression.predict(a)
print(str(ans[0][0]))
# Out:
# 381702455.13787633
