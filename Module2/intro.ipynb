# %%
import pandas as pd
data = pd.read_csv('lsd_math_score_data.csv')

# %%
print(data)
print(type(data))
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97
# <class 'pandas.core.frame.DataFrame'>

# %%
data['highScore'] = data['highScore']**2
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score   highScore
# 0                      5     1.17                78.93  32015.9449
# 1                     15     2.97                58.20  25027.2400
# 2                     30     3.26                67.47  28046.2009
# 3                     60     4.69                37.47  18898.0009
# 4                    120     5.83                45.65  21213.9225
# 5                    240     6.00                32.92  17667.7264
# 6                    480     6.41                29.97  16892.2009

# %%
onlyMathScore = data['Avg_Math_Test_Score']
print(type(onlyMathScore))
# Out:
# <class 'pandas.core.series.Series'>

# %%
columnList = data[['Avg_Math_Test_Score', 'LSD_ppm']]
print(columnList)
print(type(columnList))
# Out:
#    Avg_Math_Test_Score  LSD_ppm
# 0                78.93     1.17
# 1                58.20     2.97
# 2                67.47     3.26
# 3                37.47     4.69
# 4                45.65     5.83
# 5                32.92     6.00
# 6                29.97     6.41
# <class 'pandas.core.frame.DataFrame'>

# %%
score = data['Avg_Math_Test_Score']
LSD = data['LSD_ppm']
import matplotlib.pyplot as plt

# %%
plt.title('XYZ', fontsize=17)
plt.plot(score, LSD, color='#BDBDBD',linewidth=3, animated=True)
plt.text(x=40, y=4, s='ABC')
plt.show()

# %%
plt.title('ABC')
plt.scatter([score], [LSD], alpha=0.8)
plt.show()
